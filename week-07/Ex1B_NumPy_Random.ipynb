# %% [markdown]
# # Exercise 1.B NumPy Random

# %%
import numpy as np

# %% [markdown]
# ## Generating Random Numbers

# %%
r_1 = np.random.randint(1, 20, size = 2)
print(r_1)
# Out:
# [ 5 12]

# %%
r_2 = np.random.randint(1, 20, size = [1,2])
print(r_2)
# Out:
# [[6 9]]

# %%
r_3 = np.random.random(size = [2, 1])
print(r_3)
# Out:
# [[0.47505098]
#  [0.44327856]]

# %%
r_4 = np.random.randint(20, 100, size = [4, 5])
print(r_4)
# Out:
# [[41 92 80 38 30]
#  [66 33 24 77 54]
#  [52 36 23 25 26]
#  [26 32 68 97 24]]

# %%
r_5 = np.random.random(size = [4, 5])
print(r_5)
# Out:
# [[0.68257389 0.05608816 0.13501526 0.41776    0.48906262]
#  [0.46210969 0.407526   0.8069745  0.57327413 0.0786148 ]
#  [0.01722426 0.57324795 0.48324932 0.90945284 0.33635884]
#  [0.82128202 0.75082973 0.29092713 0.28539291 0.74297532]]

# %% [markdown]
# ## Generating Random Choices from an Array

# %%
students = ["Sharleen Guerrero",
             "Sha'Rya Weaver",
             "Vesna Cari",
             "Cris Ramirez",
             "Aspenne Rhoden",
             "Chantal Lee",
             "Demy Melgar", 
             "Dania Kabakibi",
             "Dimitri Nji",
             "Hamzah Alssoudi",
             "Hana Tilahun",
             "Ivana Nwaobi"]

# %%
arr1 = np.array(students)
print(arr1)
# Out:
# ['Sharleen Guerrero' "Sha'Rya Weaver" 'Vesna Cari' 'Cris Ramirez'
#  'Aspenne Rhoden' 'Chantal Lee' 'Demy Melgar' 'Dania Kabakibi'
#  'Dimitri Nji' 'Hamzah Alssoudi' 'Hana Tilahun' 'Ivana Nwaobi']

# %%
call_on = np.random.choice(students)
print(call_on)
# Out:
# Cris Ramirez

# %%
breakout_groups = np.random.choice(students, size = [3, 4])
print(breakout_groups)

# This would not be an effective function to use to create breakout groups because student's names are being repeated more than once for each group and then some students have been excluded from this as well. In essence, this makes this ineffective and it will only lead to confusion unless another function is able to generate different groups for all twelve students listed.
# Out:
# [['Sharleen Guerrero' 'Sharleen Guerrero' 'Hamzah Alssoudi'
#   'Hana Tilahun']
#  ['Demy Melgar' 'Vesna Cari' 'Chantal Lee' 'Sharleen Guerrero']
#  ['Chantal Lee' 'Aspenne Rhoden' 'Dania Kabakibi' 'Sharleen Guerrero']]

# %%
call_on_weighted = np.random.choice(students, size = 5, p = [0.0, 0.1, 0.2, 0.3, 0.1, 0.1, 0.0, 0.1, 0.0, 0.1, 0.0, 0.0])
print(call_on_weighted)

# The reason in which I assigned most of the students 0.0 or even 0.1 is because had I used other values, then the output would have been bigger than 1.0 or 1, which is not what we wanted. So I determined that in order to get 1.0, I would have to stay within the 0.0 to the 0.3 range for numbers.
# Out:
# ['Dania Kabakibi' 'Aspenne Rhoden' 'Cris Ramirez' 'Hamzah Alssoudi'
#  'Cris Ramirez']

# %% [markdown]
# ## Generating a Normal Distribution

# %%
bell_curve = np.random.normal(10, 5, size = [4, 5])
print(bell_curve)
# Out:
# [[15.12233351  1.65484637  2.56622495 13.52897089  8.9394716 ]
#  [12.91776808  6.9089522  19.79616401  7.6140906   9.87138032]
#  [10.96137363  8.91564189 -1.12838442  6.58447054  9.09979902]
#  [-2.19175417  7.65282569  5.92424644  9.82384595  5.73165845]]
