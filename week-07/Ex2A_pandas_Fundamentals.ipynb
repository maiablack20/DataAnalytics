# %% [markdown]
# # Exercise 2.A Fundamentals of pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series

# %%
aa = [1, 2, 3, 4]
ab = (5, 6, 7, 8)
ac = {9, 10, 11, 12}
ad = {'first': 13, 'second': 14, 'third': 15, 'fourth': 16}

# %%
ser1 = pd.Series(aa)
print(ser1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
ser2 = pd.Series(ab)
print(ser2)
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# dtype: int64

# %%
ser3 = pd.Series(ac)
print(ser3)

# TypeError since this is an unordered 'set' type.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ser3 = pd.Series(ac)
#       2 print(ser3)
#       4 # TypeError since this is an unordered 'set' type.
#
# File ~\New folder\Lib\site-packages\pandas\core\series.py:587, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     585         data = data.copy()
#     586 else:
# --> 587     data = sanitize_array(data, index, dtype, copy)
#     589     manager = _get_option("mode.data_manager", silent=True)
#     590     if manager == "block":
#
# File ~\New folder\Lib\site-packages\pandas\core\construction.py:639, in sanitize_array(data, index, dtype, copy, allow_2d)
#     630     return sanitize_array(
#     631         data,
#     632         index=index,
#    (...)    635         allow_2d=allow_2d,
#     636     )
#     638 else:
# --> 639     _sanitize_non_ordered(data)
# ...

# %%
ser4 = pd.Series(ad)
print(ser4)
# Out:
# first     13
# second    14
# third     15
# fourth    16
# dtype: int64

# %%
ser5 = pd.Series(17, 18, 19, 20)
print(ser5)

# The error that was provided as a result of this is a TypeError, which stated that the index must be called with a collection of some kind, even though 18 was passed.

# %% [markdown]
# ## DataFrames from Series

# %%
print(ser1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
df1 = pd.DataFrame(ser1)
df1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df1.insert(1, "1", ser2)
pd.DataFrame(df1)
df1
# Out:
#    0  1
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
print(ser4)
# Out:
# first     13
# second    14
# third     15
# fourth    16
# dtype: int64

# %%
df1.insert(2, "2", ser4)
pd.DataFrame(df1)
df1
# Out:
#    0  1   2
# 0  1  5 NaN
# 1  2  6 NaN
# 2  3  7 NaN
# 3  4  8 NaN

# %%
# What happens when I call df1 after inserting ser4 into the DataFrame is that it returns NaN, which means that the values for ser4 were much more different than the others because it's a dictionary rather than a list and/or tuple of values.

# %%
df1.loc[4] = [5, 9, 12]
pd.DataFrame(df1)
df1
# Out:
#    0  1     2
# 0  1  5   NaN
# 1  2  6   NaN
# 2  3  7   NaN
# 3  4  8   NaN
# 4  5  9  12.0

# %% [markdown]
# ## Reading Data into a DataFrame

# %%
df2 = pd.read_csv("sakila_example.csv")
df2
# Out:
#                  title                                        description  \
# 0     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 1     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 2     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 3     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 4     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# ..                 ...                                                ...
# 257  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 258  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 259        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 260        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 261        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
#
#         category language        actor_name
# ...

# %%
df2.tail(10)
df2
# Out:
#                  title                                        description  \
# 0     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 1     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 2     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 3     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 4     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# ..                 ...                                                ...
# 257  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 258  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 259        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 260        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 261        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
#
#         category language        actor_name
# ...

# %%
df2.info()
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        262 non-null    object
#  1   description  262 non-null    object
#  2   category     262 non-null    object
#  3   language     262 non-null    object
#  4   actor_name   262 non-null    object
# dtypes: object(5)
# memory usage: 10.4+ KB
#                  title                                        description  \
# 0     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 1     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 2     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 3     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 4     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# ..                 ...                                                ...
# ...

# %% [markdown]
# #### The few facts I can determine about this data is that the data type is objects(5), which means the movies are classified as objects, the memory usage this takes up is about 10.4+ KB, there is a 262 non-null count of the items within each category, and due to the limited space for Jupyter Notebook, it can only show a certain amount of films that are listed.

# %%
df2.describe()
df2
# Out:
#                  title                                        description  \
# 0     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 1     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 2     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 3     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 4     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# ..                 ...                                                ...
# 257  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 258  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 259        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 260        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 261        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
#
#         category language        actor_name
# ...

# %% [markdown]
# #### The results that I was provided from this is a description of the films from the sakila database, which gives me a little insight on what the movies are about. I would say the summarizations that are not so useful would be the ones where the information is duplicated, but again that is on the fact that Jupyter Notebook has limited space to list all the information.

# %%
df3 = pd.read_csv("northwind_example.csv")
df3
# Out:
#      OrderID                    ProductName  UnitPrice  Quantity
# 0      10248                 Queso Cabrales       14.0        12
# 1      10248  Singaporean Hokkien Fried Mee        9.8        10
# 2      10248         Mozzarella di Giovanni       34.8         5
# 3      10249          Manjimup Dried Apples       42.4        40
# 4      10249                           Tofu       18.6         9
# ..       ...                            ...        ...       ...
# 495    10435         Mozzarella di Giovanni       27.8        10
# 496    10436         Gnocchi di nonna Alice       30.4        40
# 497    10436       Wimmers gute Semmelkndel       26.6        30
# 498    10436             Rhnbru Klosterbier        6.2        24
# 499    10436                      Spegesild        9.6         5
#
# [500 rows x 4 columns]

# %%
df3.describe()
df3
# Out:
#      OrderID                    ProductName  UnitPrice  Quantity
# 0      10248                 Queso Cabrales       14.0        12
# 1      10248  Singaporean Hokkien Fried Mee        9.8        10
# 2      10248         Mozzarella di Giovanni       34.8         5
# 3      10249          Manjimup Dried Apples       42.4        40
# 4      10249                           Tofu       18.6         9
# ..       ...                            ...        ...       ...
# 495    10435         Mozzarella di Giovanni       27.8        10
# 496    10436         Gnocchi di nonna Alice       30.4        40
# 497    10436       Wimmers gute Semmelkndel       26.6        30
# 498    10436             Rhnbru Klosterbier        6.2        24
# 499    10436                      Spegesild        9.6         5
#
# [500 rows x 4 columns]

# %% [markdown]
# ##### The describe function for df2 is different because it showed the description of the films within the sakila databases. However, for df3, the describe function did not show anything new at all. The only description I receive for the products in df3 is in the name, but nothing else.

# %% [markdown]
# ## Coding a DataFrame

# %%
test_data = {'ID': [1, 2, 3, 4, 5, 6, 7, 8],
             'Name': ['Alicia', 'Bob', 'Charlie', 'Dominic', 'Eve', 'Frank', 'Grace', 'Heidi'],
             'Age': [25, np.nan, 22, 19, 31, 35, np.nan, 18],
             'City': ['NY', 'LA', 'Chicago', 'Houston', 'Phoenix', 'Boston', 'Austin', 'San Diego'], 
             'Score': [85, 92, -1, 65, 78, np.nan, 55, 90]}

# %%
df4 = pd.DataFrame(test_data)
df4
# Out:
#    ID     Name   Age       City  Score
# 0   1   Alicia  25.0         NY   85.0
# 1   2      Bob   NaN         LA   92.0
# 2   3  Charlie  22.0    Chicago   -1.0
# 3   4  Dominic  19.0    Houston   65.0
# 4   5      Eve  31.0    Phoenix   78.0
# 5   6    Frank  35.0     Boston    NaN
# 6   7    Grace   NaN     Austin   55.0
# 7   8    Heidi  18.0  San Diego   90.0

# %%
df4.to_csv("test_data.csv")
df4
# Out:
#    ID     Name   Age       City  Score
# 0   1   Alicia  25.0         NY   85.0
# 1   2      Bob   NaN         LA   92.0
# 2   3  Charlie  22.0    Chicago   -1.0
# 3   4  Dominic  19.0    Houston   65.0
# 4   5      Eve  31.0    Phoenix   78.0
# 5   6    Frank  35.0     Boston    NaN
# 6   7    Grace   NaN     Austin   55.0
# 7   8    Heidi  18.0  San Diego   90.0
